# %%
input_data = None
input_doc = None
output_data = None
util = None
display_util = None

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib_inline

# from IPython.display import Markdown

matplotlib_inline.backend_inline.set_matplotlib_formats("svg")


# %matplotlib inline
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", None)

sys.path.append(str(Path(util).parent))
sys.path.append(str(Path(display_util).parent))

# %%
from display_util import (  # noqa: E402
    rename,
    display_data_doc,
)
from util import (  # noqa: E402
    drop_col_few_distinct,
    drop_duplicate_columns,
)

# %% [markdown]
# # spender_postmortem_labor_klinische_chemie
#
# Clinical lab test results for are provided by {term}`ET`, {term}`IQTIG` and {term}`DSO` in the file `element_spender_postmortem_labor_klinische_chemie.csv`.
#
# We perform the common steps outlined in [](../02_preprocessing/index.md). We drop the {term}`IQTIG` data and remove certain columns, which appear to use the wrong units.
#
# ## Unprocessed input data

# %%
data = pd.read_csv(input_data, sep=";", low_memory=False)
display_data_doc(data=data, official_doc=pd.read_csv(input_doc))

# %% [markdown]
# ## Technical Steps
#
# For this file the general plan for technical preprocessing was followed.
#
# ### Removal of Non-Informative Columns
#
# First empty and duplicated columns were removed (see [](general:ecf)). We do not use the {term}`DSO` identifiers, so the column `SPostmLaborKCIdDSOKennnummerDSO` was also removed.

# %%
data = drop_col_few_distinct(data)
data = drop_duplicate_columns(data).drop(columns="SPostmLaborKCIdDSOKennnummerDSO")

# %% [markdown]
# ### Renaming of Columns
#
# New names were used for the columns. (see [](general:cr)).

# %%
renaming = {
    "SPostmLaborKCAlbuminEinheitDSO": "albumin_unit_dso",
    "SPostmLaborKCAlkPhosphataseEinheitDSO": "alkaline_phosphatase_unit_dso",
    "SPostmLaborKCAmylaseEinheitDSO": "amylase_unit_dso",
    "SPostmLaborKCAPTTEinheitET": "partial_thromboplastin_time_unit_et",
    "SPostmLaborKCAT3EinheitDSO": "antithrombin_3_unit_dso",
    "SPostmLaborKCATIIIEinheitET": "antithrombin_3_unit_et",
    "SPostmLaborKCBilirubinDirektEinheitDSO": "bilirubin_direct_unit_dso",
    "SPostmLaborKCBilirubinGesamtEinheitDSO": "bilirubin_all_unit_dso",
    "SPostmLaborKCCHEEinheitDSO": "cholinesterase_unit",
    "SPostmLaborKCChloridkonzentrationEinheitDSO": "chloride_unit_dso",
    "SPostmLaborKCChloridkonzentrationEinheitET": "chloride_unit_et",
    "SPostmLaborKCCKMBEinheitDSO": "creatine_kinase_mb_unit_dso",
    "SPostmLaborKCCPKEinheitDSO": "creatine_kinase_unit_dso",
    "SPostmLaborKCCRPEinheitDSO": "c_reactive_protein_unit_dso",
    "SPostmLaborKCErythrozytenEinheitDSO": "erythrocytes_unit_dso",
    "SPostmLaborKCErythrozytenEinheitET": "erythrocytes_unit_et",
    "SPostmLaborKCFibrinogenEinheitDSO": "fibrinogen_unit_dso",
    "SPostmLaborKCGGTEinheitDSO": "gamma_glutamyltransferase_unit_dso",
    "SPostmLaborKCGLDHEinheitDSO": "glutamate_dehydrogenase_unit",
    "SPostmLaborKCGlukoseEinheitDSO": "glucose_unit_dso",
    "SPostmLaborKCGOTEinheitDSO": "glutamic_oxaloacetic_transaminase_unit_dso",
    "SPostmLaborKCGPTEinheitDSO": "alanine_transaminase_unit_dso",
    "SPostmLaborKCHaematokritEinheitDSO": "hematocrit_unit_dso",
    "SPostmLaborKCHaematokritEinheitET": "hematocrit_unit_et",
    "SPostmLaborKCHaemoglobinEinheitDSO": "hemoglobin_unit_dso",
    "SPostmLaborKCHarnstoffEinheitDSO": "urea_unit_dso",
    "SPostmLaborKCHbA1cEinheitDSO": "glycated_hemoglobin_unit_dso",
    "SPostmLaborKCHbA1cEinheitET": "glycated_hemoglobin_unit_et",
    "SPostmLaborKCKaliumkonzentrationEinheitDSO": "potassium_unit_dso",
    "SPostmLaborKCKaliumkonzentrationEinheitET": "potassium_unit_et",
    "SPostmLaborKCKalziumkonzentrationEinheitDSO": "calcium_unit_dso",
    "SPostmLaborKCKCLEinheitDSO": "creatinine_clearance_unit",
    "SPostmLaborKCKreatininEinheitDSO": "creatinine_unit_dso",
    "SPostmLaborKCKreatininLetzterEinheitIQTIG": "creatinine_unit_unitwrong_iqtig",
    "SPostmLaborKCLACEinheitDSO": "lactate_unit",
    "SPostmLaborKCLDHEinheitDSO": "lactate_dehydrogenase_unit_dso",
    "SPostmLaborKCLeukozytenEinheitDSO": "leukocytes_unit_dso_broken",
    "SPostmLaborKCLeukozytenEinheitET": "leukocytes_unit",
    "SPostmLaborKCLipaseEinheitDSO": "lipase_unit_dso",
    "SPostmLaborKCNatriumkonzentrationEinheitDSO": "sodium_unit_dso",
    "SPostmLaborKCNatriumkonzentrationEinheitET": "sodium_unit_et",
    "SPostmLaborKCPCTEinheitDSO": "procalcitonin_unit",
    "SPostmLaborKCPHOEinheitDSO": "phosphate_unit",
    "SPostmLaborKCProteinGesamtEinheitDSO": "total_protein_unit_dso",
    "SPostmLaborKCPTEinheitET": "prothrombin_time_unit",
    "SPostmLaborKCPTTEinheitDSO": "partial_thromboplastin_time_unit_dso",
    "SPostmLaborKCQuickEinheitDSO": "quick_unit_dso",
    "SPostmLaborKCQuickEinheitET": "quick_unit_et",
    "SPostmLaborKCThrombozytenEinheitDSO": "thrombocytes_unit_dso",
    "SPostmLaborKCThrombozytenEinheitET": "thrombocytes_unit_et",
    "SPostmLaborKCTroponineIEinheitDSO": "troponin_1_unit_dso",
    "SPostmLaborKCTroponineTEinheitDSO": "troponin_t_unit_dso",
    "SPostmLaborKCALPEinheitET": "alkaline_phosphatase_unit_et",
    "SPostmLaborKCALPWertET": "alkaline_phosphatase_u_per_l_et",
    "SPostmLaborKCAPTTWertET": "partial_thromboplastin_time_sec_et",
    "SPostmLaborKCAT3WertDSO": "antithrombin_3_percent_dso",
    "SPostmLaborKCATIIIWertET": "antithrombin_3_percent_et",
    "SPostmLaborKCAlbuminEinheitET": "albumin_unit_et",
    "SPostmLaborKCAlbuminWertDSO": "albumin_g_per_l_et",
    "SPostmLaborKCAlbuminWertET": "albumin_g_per_l_dso",
    "SPostmLaborKCAlkPhosphataseWertDSO": "alkaline_phosphatase_u_per_l_dso",
    "SPostmLaborKCAmylaseEinheitET": "amylase_unit_et",
    "SPostmLaborKCAmylaseWertDSO": "amylase_u_per_l_dso",
    "SPostmLaborKCAmylaseWertET": "amylase_u_per_l_et",
    "SPostmLaborKCBefundDateDSO": "result_date",
    "SPostmLaborKCBilirubinDirektEinheitET": "bilirubin_direct_unit_et",
    "SPostmLaborKCBilirubinDirektWertDSO": "bilirubin_direct_umol_per_l_dso",
    "SPostmLaborKCBilirubinDirektWertET": "bilirubin_direct_umol_per_l_et",
    "SPostmLaborKCBilirubinGesamtEinheitET": "bilirubin_all_unit_et",
    "SPostmLaborKCBilirubinGesamtWertDSO": "bilirubin_all_umol_per_l_dso",
    "SPostmLaborKCBilirubinGesamtWertET": "bilirubin_all_umol_per_l_et",
    "SPostmLaborKCCHEWertDSO": "cholinesterase_u_per_l",
    "SPostmLaborKCCKEinheitET": "creatine_kinase_unit_et",
    "SPostmLaborKCCKMBEinheitET": "creatine_kinase_mb_unit_et",
    "SPostmLaborKCCKMBWertDSO": "creatine_kinase_mb_u_per_l_dso",
    "SPostmLaborKCCKMBWertET": "creatine_kinase_mb_u_per_l_et",
    "SPostmLaborKCCKWertET": "creatine_kinase_u_per_l_et",
    "SPostmLaborKCCPKWertDSO": "creatine_kinase_u_per_l_dso",
    "SPostmLaborKCCRPEinheitET": "c_reactive_protein_unit_et",
    "SPostmLaborKCCRPWertDSO": "c_reactive_protein_mg_per_l_dso",
    "SPostmLaborKCCRPWertET": "c_reactive_protein_mg_per_l_et",
    "SPostmLaborKCCalciumkonzentrationEinheitET": "calcium_unit_et",
    "SPostmLaborKCCalciumkonzentrationWertET": "calcium_mmol_per_l_et",
    "SPostmLaborKCChloridkonzentrationWertDSO": "chloride_mmol_per_l_dso",
    "SPostmLaborKCChloridkonzentrationWertET": "chloride_mmol_per_l_et",
    "SPostmLaborKCErfahrenAmDateDSO": "communicated_date",
    "SPostmLaborKCErythrozytenWertDSO": "erythrocytes_t_per_l_dso",
    "SPostmLaborKCErythrozytenWertET": "erythrocytes_t_per_l_et",
    "SPostmLaborKCFibrinogenEinheitET": "fibrinogen_unit_et",
    "SPostmLaborKCFibrinogenWertDSO": "fibrinogen_g_per_l_dso",
    "SPostmLaborKCFibrinogenWertET": "fibrinogen_g_per_l_et",
    "SPostmLaborKCGGTEinheitET": "gamma_glutamyltransferase_unit_et",
    "SPostmLaborKCGGTWertDSO": "gamma_glutamyltransferase_u_per_l_dso",
    "SPostmLaborKCGGTWertET": "gamma_glutamyltransferase_u_per_l_et",
    "SPostmLaborKCGLDHWertDSO": "glutamate_dehydrogenase_u_per_l",
    "SPostmLaborKCGOTWertDSO": "glutamic_oxaloacetic_transaminase_u_per_l_dso",
    "SPostmLaborKCGPTWertDSO": "alanine_transaminase_u_per_l_dso",
    "SPostmLaborKCGlucoseEinheitET": "glucose_unit_et",
    "SPostmLaborKCGlucoseWertET": "glucose_mmol_per_l_et",
    "SPostmLaborKCGlukoseWertDSO": "glucose_mmol_per_l_dso",
    "SPostmLaborKCHaematokritWertDSO": "hematocrit_percent_dso",
    "SPostmLaborKCHaematokritWertET": "hematocrit_percent_et",
    "SPostmLaborKCHaemoglobinEinheitET": "hemoglobin_unit_et",
    "SPostmLaborKCHaemoglobinWertDSO": "hemoglobin_g_per_dl_dso",
    "SPostmLaborKCHaemoglobinWertET": "hemoglobin_g_per_dl_et",
    "SPostmLaborKCHarnstoffEinheitET": "urea_unit_et",
    "SPostmLaborKCHarnstoffWertDSO": "urea_mmol_per_l_dso",
    "SPostmLaborKCHarnstoffWertET": "urea_mmol_per_l_et",
    "SPostmLaborKCHbA1cWertDSO": "glycated_hemoglobin_percent_dso",
    "SPostmLaborKCHbA1cWertET": "glycated_hemoglobin_percent_et",
    "SPostmLaborKCINRET": "international_normalized_ratio_et",
    "SPostmLaborKCINRWertDSO": "international_normalized_ratio_dso",
    "SPostmLaborKCIdSpenderNrETDSO": "donor_et_dso",
    "SPostmLaborKCIdSpenderNrETET": "donor_et_id_et",
    "SPostmLaborKCIdSpenderNrETIQTIG": "donor_et_iqtig",
    "SPostmLaborKCKCLWertDSO": "creatinine_clearance_ml_per_min",
    "SPostmLaborKCKaliumkonzentrationWertDSO": "potassium_mmol_per_l_dso",
    "SPostmLaborKCKaliumkonzentrationWertET": "potassium_mmol_per_l_et",
    "SPostmLaborKCKalziumkonzentrationWertDSO": "calcium_mmol_per_l_dso",
    "SPostmLaborKCKreatininEinheitET": "creatinine_unit_et",
    "SPostmLaborKCKreatininLetzterWertIQTIG": "creatinine_mg_per_dl_unitwrong_iqtig",
    "SPostmLaborKCKreatininWertDSO": "creatinine_umol_per_l_dso_broken",
    "SPostmLaborKCKreatininWertET": "creatinine_umol_per_l",
    "SPostmLaborKCLACWertDSO": "lactate_mmol_per_l",
    "SPostmLaborKCLDHEinheitET": "lactate_dehydrogenase_unit_et",
    "SPostmLaborKCLDHWertDSO": "lactate_dehydrogenase_u_per_l_dso",
    "SPostmLaborKCLDHWertET": "lactate_dehydrogenase_u_per_l_et",
    "SPostmLaborKCLeukozytenWertDSO": "leukocytes_g_per_l_dso_broken",
    "SPostmLaborKCLeukozytenWertET": "leukocytes_g_per_l",
    "SPostmLaborKCLipaseEinheitET": "lipase_unit_et",
    "SPostmLaborKCLipaseWertDSO": "lipase_u_per_l_dso",
    "SPostmLaborKCLipaseWertET": "lipase_u_per_l_et",
    "SPostmLaborKCNatriumkonzentrationWertDSO": "sodium_mmol_per_l_dso",
    "SPostmLaborKCNatriumkonzentrationWertET": "sodium_mmol_per_l_et",
    "SPostmLaborKCPCTWertDSO": "procalcitonin_ng_per_ml",
    "SPostmLaborKCPHOWertDSO": "phosphate_mmol_per_l",
    "SPostmLaborKCPTTWertDSO": "partial_thromboplastin_time_sec_dso",
    "SPostmLaborKCPTWertET": "prothrombin_time_sec",
    "SPostmLaborKCProbeDateDSO": "sampling_date_dso",
    "SPostmLaborKCProbeDateET": "sampling_date_et",
    "SPostmLaborKCProbenmaterialDSO": "tissue",
    "SPostmLaborKCProteinGesamtEinheitET": "total_protein_unit_et",
    "SPostmLaborKCProteinGesamtWertDSO": "total_protein_g_per_l_dso",
    "SPostmLaborKCProteinGesamtWertET": "total_protein_g_per_l_et",
    "SPostmLaborKCQuickWertDSO": "quick_percent_dso",
    "SPostmLaborKCQuickWertET": "quick_percent_et",
    "SPostmLaborKCSGOTASATEinheitET": "glutamic_oxaloacetic_transaminase_unit_et",
    "SPostmLaborKCSGOTASATWertET": "glutamic_oxaloacetic_transaminase_u_per_l_et",
    "SPostmLaborKCSGPTALATEinheitET": "alanine_transaminase_unit_et",
    "SPostmLaborKCSGPTALATWertET": "alanine_transaminase_u_per_l_et",
    "SPostmLaborKCThrombozytenWertDSO": "thrombocytes_g_per_l_dso",
    "SPostmLaborKCThrombozytenWertET": "thrombocytes_g_per_l_et",
    "SPostmLaborKCTroponineEinheitET": "troponin_unit",
    "SPostmLaborKCTroponineIEinheitET": "troponin_1_unit_et",
    "SPostmLaborKCTroponineIWertDSO": "troponin_1_ug_per_l_dso",
    "SPostmLaborKCTroponineIWertET": "troponin_1_ug_per_l_et",
    "SPostmLaborKCTroponineTEinheitET": "troponin_t_unit_et",
    "SPostmLaborKCTroponineTWertDSO": "troponin_t_ug_per_l_dso",
    "SPostmLaborKCTroponineTWertET": "troponin_t_ug_per_l_et",
    "SPostmLaborKCTroponineWertET": "troponin_ug_per_l",
    "SPostmLaborKCUntersuchungDateDSO": "examination_date",
}

data = rename(data, renaming)
data.to_parquet(output_data)
